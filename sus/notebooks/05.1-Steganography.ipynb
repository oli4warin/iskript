# %%
from gymmu.images import *
import numpy as np

img = Image.open("res/security.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=448x274 at 0x7F22144B9490>

# %%
arr = np.array(img)
print(arr.shape)
# Out:
# (274, 448)

# %%
hidden = [
    (0, 0),
    (10, 51),
    (65, 3),
    (13, 9),
    (0, 128)
]
msg = 'hello'

# %%
for i, c in zip(hidden, msg):
    arr[i] = ord(c)

# %%
img2 = Image.fromarray(arr.astype(np.uint8))
display(img2)
# Out:
# <PIL.Image.Image image mode=L size=448x274 at 0x7F22191E2D30>

# %%
hidden = [
    (0, 0),
    (10, 51),
    (65, 3),
    (13, 9),
    (0, 128)
]
for i in hidden:
    print(chr(arr[i]))
# Out:
# h
# e
# l
# l
# o
